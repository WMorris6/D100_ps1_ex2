# %%
from fed.load_data import load_gdp_data

# %%
countries = ['GB', 'CN', 'JP', 'DE', 'CH']
df = load_gdp_data(countries)

df.head()
# Out:
# Saved GDP data to data/gdp_data.csv
# /Users/will/Documents/GitHub/D100_ps1_ex2/fed/load_data.py:12: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = wb.download(
#        country  year           gdp
# 0  Switzerland  2022  8.285089e+11
# 1  Switzerland  2021  8.153093e+11
# 2  Switzerland  2020  7.419994e+11
# 3  Switzerland  2019  7.213691e+11
# 4  Switzerland  2018  7.255687e+11

# %%
from fed.clean_data import clean_gdp_data

df_clean = clean_gdp_data(df)
df_clean.head()
# Out:
#    country  year           gdp  gdp_trillions
# 45   China  2000  1.223755e+12       1.223755
# 44   China  2001  1.355037e+12       1.355037
# 43   China  2002  1.489822e+12       1.489822
# 42   China  2003  1.683903e+12       1.683903
# 41   China  2004  1.984197e+12       1.984197

# %%
from fed.visualise_data import plot_gdp

plot_gdp(df_clean)
